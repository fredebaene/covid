# %% [markdown]
# ### COVID-19 - CONFIRMED CASES BY DATE, PROVINCE, AGE, AND SEX

# %% [markdown]
# ###### IMPORTING LIBRARIES

# %%
import pandas as pd
import plotly
import plotly.express as px

# %% [markdown]
# ###### READING DATA

# %%
data = pd.read_csv('../data/covid19be_cases_agesex.csv')

# %% [markdown]
# ###### EXPLORING DATA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56270 entries, 0 to 56269
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATE      56221 non-null  object
#  1   PROVINCE  52739 non-null  object
#  2   REGION    52739 non-null  object
#  3   AGEGROUP  54734 non-null  object
#  4   SEX       55382 non-null  object
#  5   CASES     56270 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 2.6+ MB

# %%
data.head()
# Out:
#          DATE   PROVINCE    REGION AGEGROUP SEX  CASES
# 0  2020-03-01  Antwerpen  Flanders    40-49   M      1
# 1  2020-03-01   Brussels  Brussels    10-19   F      1
# 2  2020-03-01   Brussels  Brussels    10-19   M      1
# 3  2020-03-01   Brussels  Brussels    20-29   M      1
# 4  2020-03-01   Brussels  Brussels    30-39   F      1

# %%
data.tail()
# Out:
#       DATE        PROVINCE    REGION AGEGROUP  SEX  CASES
# 56265  NaN   VlaamsBrabant  Flanders    40-49    M      3
# 56266  NaN   VlaamsBrabant  Flanders    50-59    M      1
# 56267  NaN  WestVlaanderen  Flanders    20-29    F      1
# 56268  NaN  WestVlaanderen  Flanders    50-59    M      3
# 56269  NaN             NaN       NaN      NaN  NaN      1

# %%
nan_counts = [(i, data[i].isna().sum()) for i in data.columns]
nan_counts
# Out:
# [('DATE', 49),
#  ('PROVINCE', 3531),
#  ('REGION', 3531),
#  ('AGEGROUP', 1536),
#  ('SEX', 888),
#  ('CASES', 0)]

# %%
data['DATE'].isna().sum() # calculate number of NA values
# Out:
# 49

# %%
data['PROVINCE'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# NaN               3531
# Antwerpen         5792
# BrabantWallon     3709
# Brussels          5594
# Hainaut           5213
# Limburg           4822
# Liège             5043
# Luxembourg        3296
# Namur             3899
# OostVlaanderen    5215
# VlaamsBrabant     4929
# WestVlaanderen    5227
# Name: PROVINCE, dtype: int64

# %%
data['REGION'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# NaN          3531
# Brussels     5594
# Flanders    25985
# Wallonia    21160
# Name: REGION, dtype: int64

# %%
data['AGEGROUP'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# NaN      1536
# 0-9      3979
# 10-19    5107
# 20-29    6571
# 30-39    6457
# 40-49    6494
# 50-59    6341
# 60-69    5688
# 70-79    5208
# 80-89    5105
# 90+      3784
# Name: AGEGROUP, dtype: int64

# %%
data['SEX'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# NaN      888
# F      28233
# M      27149
# Name: SEX, dtype: int64

# %% [markdown]
# ###### CLEANING DATA

# %%
data.dropna(axis=0, how='any', thresh=None, subset=['DATE'], inplace=True)

# %%
for i in ['PROVINCE', 'REGION', 'AGEGROUP', 'SEX']:
    data[i].fillna('MISSING', inplace=True)

# %%
data['DATE'].isna().sum()
# Out:
# 0

# %%
data['PROVINCE'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# Antwerpen         5788
# BrabantWallon     3705
# Brussels          5587
# Hainaut           5208
# Limburg           4821
# Liège             5030
# Luxembourg        3295
# MISSING           3530
# Namur             3898
# OostVlaanderen    5208
# VlaamsBrabant     4926
# WestVlaanderen    5225
# Name: PROVINCE, dtype: int64

# %%
data['REGION'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# Brussels     5587
# Flanders    25968
# MISSING      3530
# Wallonia    21136
# Name: REGION, dtype: int64

# %%
data['AGEGROUP'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# 0-9        3979
# 10-19      5105
# 20-29      6566
# 30-39      6452
# 40-49      6483
# 50-59      6333
# 60-69      5685
# 70-79      5204
# 80-89      5101
# 90+        3784
# MISSING    1529
# Name: AGEGROUP, dtype: int64

# %%
data['SEX'].value_counts(dropna=False).sort_index(na_position='first')
# Out:
# F          28213
# M          27121
# MISSING      887
# Name: SEX, dtype: int64

# %%
data['DATE'] = pd.to_datetime(data['DATE'], format='%Y-%m-%d')

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ###### DATA ANALYSIS

# %%
data_by_date = data.resample('D', on='DATE')['CASES'].sum().reset_index()
data_by_date.head(10)
# Out:
#         DATE  CASES
# 0 2020-03-01     19
# 1 2020-03-02     19
# 2 2020-03-03     34
# 3 2020-03-04     53
# 4 2020-03-05     81
# 5 2020-03-06    110
# 6 2020-03-07     27
# 7 2020-03-08     64
# 8 2020-03-09     94
# 9 2020-03-10     99

# %%
data_by_province_date = data.groupby(by=['PROVINCE'], dropna=False).resample('D', on='DATE')['CASES'].sum().reset_index()
data_by_province_date.head(10)
# Out:
#     PROVINCE       DATE  CASES
# 0  Antwerpen 2020-03-01      1
# 1  Antwerpen 2020-03-02      1
# 2  Antwerpen 2020-03-03      5
# 3  Antwerpen 2020-03-04      6
# 4  Antwerpen 2020-03-05     11
# 5  Antwerpen 2020-03-06     11
# 6  Antwerpen 2020-03-07      8
# 7  Antwerpen 2020-03-08      9
# 8  Antwerpen 2020-03-09      8
# 9  Antwerpen 2020-03-10     14

# %%
data_by_agegroup_date = data.groupby(by=['AGEGROUP'], dropna=False).resample('D', on='DATE')['CASES'].sum().reset_index()
data_by_agegroup_date.head(10)
# Out:
#   AGEGROUP       DATE  CASES
# 0      0-9 2020-03-03      1
# 1      0-9 2020-03-04      3
# 2      0-9 2020-03-05      3
# 3      0-9 2020-03-06      2
# 4      0-9 2020-03-07      0
# 5      0-9 2020-03-08      0
# 6      0-9 2020-03-09      2
# 7      0-9 2020-03-10      1
# 8      0-9 2020-03-11      4
# 9      0-9 2020-03-12      4

# %%
data_by_province_agegroup_date = data.groupby(by=['PROVINCE', 'AGEGROUP'], dropna=False).resample('D', on='DATE')['CASES'].sum().reset_index()
data_by_province_agegroup_date.head(10)
# Out:
#     PROVINCE AGEGROUP       DATE  CASES
# 0  Antwerpen      0-9 2020-03-04      1
# 1  Antwerpen      0-9 2020-03-05      1
# 2  Antwerpen      0-9 2020-03-06      0
# 3  Antwerpen      0-9 2020-03-07      0
# 4  Antwerpen      0-9 2020-03-08      0
# 5  Antwerpen      0-9 2020-03-09      0
# 6  Antwerpen      0-9 2020-03-10      0
# 7  Antwerpen      0-9 2020-03-11      1
# 8  Antwerpen      0-9 2020-03-12      0
# 9  Antwerpen      0-9 2020-03-13      0

# %% [markdown]
# ###### DATA VISUALIZATION

# %%
# cases by date
fig_cases_by_date = px.line(
    data_frame=data_by_date,
    x='DATE',
    y='CASES',
    labels={'CASES' : 'Confirmed Cases', 'DATE' : 'Date'},
    title='Confirmed Cases by Date'
)

fig_cases_by_date.show()
# Out:
# <div>                            <div id="3b2e842c-4daa-4a4d-b522-ce1be623c51c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b2e842c-4daa-4a4d-b522-ce1be623c51c")) {                    Plotly.newPlot(                        "3b2e842c-4daa-4a4d-b522-ce1be623c51c",                        [{"hovertemplate": "Date=%{x}<br>Confirmed Cases=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-07T00:00:00", "2020-03-08T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-14T00:00:00", "2020-03-15T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-21T00:00:00", "2020-03-22T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-28T00:00:00", "2020-03-29T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00", "2020-04-05T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-10T00:00:00", "2020-04-11T00:00:00", "2020-04-12T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-18T00:00:00", "2020-04-19T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-25T00:00:00", "2020-04-26T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-03T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-23T00:00:00", "2020-05-24T00:00:00", "2020-05-25T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-05-30T00:00:00", "2020-05-31T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-06T00:00:00", "2020-06-07T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-13T00:00:00", "2020-06-14T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-20T00:00:00", "2020-06-21T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-27T00:00:00", "2020-06-28T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00", "2020-07-05T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-11T00:00:00", "2020-07-12T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-18T00:00:00", "2020-07-19T00:00: ...

# %%
# cases by province
fig_cases_by_province = px.line(
    data_frame=data_by_province_date,
    x='DATE',
    y='CASES',
    line_group='PROVINCE',
    color='PROVINCE',
    labels={'CASES' : 'Confirmed Cases', 'PROVINCE' : 'Province', 'DATE' : 'Date'},
    title='Confirmed Cases by Province'
)

fig_cases_by_province.show()
# Out:
# <div>                            <div id="ce031dcc-c608-4ede-a73b-039b3ae47071" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce031dcc-c608-4ede-a73b-039b3ae47071")) {                    Plotly.newPlot(                        "ce031dcc-c608-4ede-a73b-039b3ae47071",                        [{"hovertemplate": "Province=Antwerpen<br>Date=%{x}<br>Confirmed Cases=%{y}<extra></extra>", "legendgroup": "Antwerpen", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Antwerpen", "showlegend": true, "type": "scattergl", "x": ["2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-07T00:00:00", "2020-03-08T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-14T00:00:00", "2020-03-15T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-21T00:00:00", "2020-03-22T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-28T00:00:00", "2020-03-29T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00", "2020-04-05T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-10T00:00:00", "2020-04-11T00:00:00", "2020-04-12T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-18T00:00:00", "2020-04-19T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-25T00:00:00", "2020-04-26T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-03T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-23T00:00:00", "2020-05-24T00:00:00", "2020-05-25T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-05-30T00:00:00", "2020-05-31T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-06T00:00:00", "2020-06-07T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-13T00:00:00", "2020-06-14T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-20T00:00:00", "2020-06-21T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-27T00:00:00", "2020-06-28T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00", "2020-07-05T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-11T00:00:00", "2020-07-12T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-18T00:00:00 ...

# %%
# cases by age group
fig_cases_by_agegroup = px.line(
    data_frame=data_by_agegroup_date,
    x='DATE',
    y='CASES',
    line_group='AGEGROUP',
    color='AGEGROUP',
    labels={'CASES' : 'Confirmed Cases', 'AGEGROUP' : 'Age Group', 'DATE' : 'Date'},
    title='Confirmed Cases by Age Group'
)

fig_cases_by_agegroup.show()
# Out:
# <div>                            <div id="adf744f4-a17e-4528-9f07-a4eb1f497670" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adf744f4-a17e-4528-9f07-a4eb1f497670")) {                    Plotly.newPlot(                        "adf744f4-a17e-4528-9f07-a4eb1f497670",                        [{"hovertemplate": "Age Group=0-9<br>Date=%{x}<br>Confirmed Cases=%{y}<extra></extra>", "legendgroup": "0-9", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "0-9", "showlegend": true, "type": "scattergl", "x": ["2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-07T00:00:00", "2020-03-08T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-14T00:00:00", "2020-03-15T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-21T00:00:00", "2020-03-22T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-28T00:00:00", "2020-03-29T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00", "2020-04-05T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-10T00:00:00", "2020-04-11T00:00:00", "2020-04-12T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-18T00:00:00", "2020-04-19T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-25T00:00:00", "2020-04-26T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-03T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-23T00:00:00", "2020-05-24T00:00:00", "2020-05-25T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-05-30T00:00:00", "2020-05-31T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-06T00:00:00", "2020-06-07T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-13T00:00:00", "2020-06-14T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-20T00:00:00", "2020-06-21T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-27T00:00:00", "2020-06-28T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-03T00:00:00", "2020-07-04T00:00:00", "2020-07-05T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-11T00:00:00", "2020-07-12T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-18T00:00:00", "2020-07-19T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00 ...
