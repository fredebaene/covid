# %% [markdown]
# ### COVID-19

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('COVID19BE_tests.csv')

# %% [markdown]
# EXPLORING DATA

# %%
len(data) # print out the number of rows
# Out:
# 3984

# %%
data.shape # print out the number of rows and columns as a tuple
# Out:
# (3984, 5)

# %%
data.info() # print out detailed information about the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3984 entries, 0 to 3983
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           3984 non-null   object
#  1   PROVINCE       3652 non-null   object
#  2   REGION         3652 non-null   object
#  3   TESTS_ALL      3984 non-null   int64
#  4   TESTS_ALL_POS  3984 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 155.8+ KB

# %%
data
# Out:
#             DATE        PROVINCE    REGION  TESTS_ALL  TESTS_ALL_POS
# 0     2020-03-01       Antwerpen  Flanders         18              0
# 1     2020-03-01   BrabantWallon  Wallonia          8              0
# 2     2020-03-01        Brussels  Brussels          4              0
# 3     2020-03-01         Hainaut  Wallonia          5              0
# 4     2020-03-01           Liège  Wallonia          8              0
# ...          ...             ...       ...        ...            ...
# 3979  2021-01-26             NaN       NaN         60              0
# 3980  2021-01-26           Namur  Wallonia          3              0
# 3981  2021-01-26  OostVlaanderen  Flanders        345             19
# 3982  2021-01-26   VlaamsBrabant  Flanders        237              6
# 3983  2021-01-26  WestVlaanderen  Flanders        517             13
#
# [3984 rows x 5 columns]

# %%
data.describe() # returns basic statistics for numerical data
# Out:
#           TESTS_ALL  TESTS_ALL_POS
# count   3984.000000    3984.000000
# mean    2001.385793     193.945532
# std     2039.182745     398.550462
# min        0.000000       0.000000
# 25%      546.000000      18.000000
# 50%     1278.500000      60.000000
# 75%     2759.000000     195.250000
# max    11967.000000    4498.000000

# %%
data.describe(include = np.object)
# Out:
#               DATE PROVINCE    REGION
# count         3984     3652      3652
# unique         332       11         3
# top     2020-11-26    Namur  Wallonia
# freq            12      332      1660

# %%
data.columns
# Out:
# Index(['DATE', 'PROVINCE', 'REGION', 'TESTS_ALL', 'TESTS_ALL_POS'], dtype='object')

# %%
data['PROVINCE'].unique()
# Out:
# array(['Antwerpen', 'BrabantWallon', 'Brussels', 'Hainaut', 'Liège',
#        'Limburg', 'Luxembourg', nan, 'Namur', 'OostVlaanderen',
#        'VlaamsBrabant', 'WestVlaanderen'], dtype=object)

# %%
data.dropna(axis = 0, how = 'any', inplace = True)

# %%
data['REGION'].unique()
# Out:
# array(['Flanders', 'Wallonia', 'Brussels'], dtype=object)

# %%
data['MONTH'] = data['DATE'].str.slice(5, 7)

# %%
data['MONTH']
# Out:
# 0       03
# 1       03
# 2       03
# 3       03
# 4       03
#         ..
# 3978    01
# 3980    01
# 3981    01
# 3982    01
# 3983    01
# Name: MONTH, Length: 3652, dtype: object

# %%
provinces = data.groupby(['PROVINCE'])

# %%
provinces['TESTS_ALL'].sum()
# Out:
# PROVINCE
# Antwerpen         1292618
# BrabantWallon      243168
# Brussels           795775
# Hainaut            777969
# Limburg            575364
# Liège              666365
# Luxembourg         176304
# Namur              282381
# OostVlaanderen    1156674
# VlaamsBrabant      786100
# WestVlaanderen     999476
# Name: TESTS_ALL, dtype: int64
